# %%
import Monte_Carlo as MC
from itertools import product
from frozen_lake_env import FrozenLakeEnv
from IPython.display import clear_output
import time
import numpy as np
import matplotlib.pyplot as plt
MC.main(env = FrozenLakeEnv(map_name="4x4",is_slippery=True),map_size = 4,episodes = 3000, epsilon = 0.1)
# Out:
#   (Down)
# 🤹❄️❄️❄️
# ❄️⚠️❄️⚠️
# ❄️❄️❄️⚠️
# ⚠️❄️❄️🏆
# {0: -0.22, 1: -0.32, 2: -0.29, 3: -0.31, 4: -0.2, 5: 0, 6: -0.44, 7: 0, 8: -0.1, 9: -0.0, 10: 0.02, 11: 0, 12: 0, 13: 0.25, 14: 0.56, 15: 0}

# %%
#now use SARSA
from IPython.display import clear_output
import numpy as np
from frozen_lake_env import FrozenLakeEnv
from numpy.random import random, choice
import matplotlib.pyplot as plt
import time
from SARSA import SARSA
agent = SARSA(env = FrozenLakeEnv(map_name="4x4"))
agent.train(episodes = 1000,gamma = 1.0,alpha = 0.1,epsilon = 1.0,decay_rate = 0.01)
# Out:
# [[ 0.52480911 -0.03335993  0.99388285  0.38930446]
#  [ 0.20207394 -0.94185026  0.99842724  0.55624749]
#  [ 0.22641493  0.99991369 -0.0329062   0.44194193]
#  [ 0.2103091  -0.65132156 -0.13793097 -0.03596266]
#  [-0.16478365  0.16929852 -0.89058101 -0.07599269]
#  [ 0.          0.          0.          0.        ]
#  [-0.6861894   0.99998462 -0.79410887  0.20189075]
#  [ 0.          0.          0.          0.        ]
#  [-0.05901677 -0.5217031   0.39727652 -0.08293412]
#  [-0.04025431  0.10380114  0.7475737  -0.5217031 ]
#  [ 0.17938877  0.99999864 -0.86491483  0.46947425]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]
#  [-0.40951     0.00719004  0.80347056 -0.040951  ]
#  [ 0.41043557  0.4798452   1.          0.41308472]
#  [ 0.          0.          0.          0.        ]]

# %%
agent.test(episodes_test=1)
# Out:
#   (Right)
# 🤹❄️❄️❄️
# ❄️⚠️❄️⚠️
# ❄️❄️❄️⚠️
# ⚠️❄️❄️🏆
# steps are 6 .

# %%
# Use Q learning
import numpy as np
import pandas as pd
import time
from matplotlib import pyplot as plt
from frozen_lake_env import FrozenLakeEnv
from IPython.display import clear_output
from numpy.random import random, choice
from Q_L import QFrozenLakeAgent
import Q_L

agent = QFrozenLakeAgent(env=FrozenLakeEnv(map_name="4x4") )
agent.train()
Q_L.test(agent, num_episodes=1)
agent.plot()
# Out:
# [[ 1.90461147e-05  5.18222550e-01  2.34838515e-07  7.62588664e-05]
#  [ 3.87692656e-05 -1.57056807e-01  1.21942144e-13  5.94789106e-12]
#  [ 6.98427302e-10  1.62063559e-15  1.62063559e-15  1.72803021e-15]
#  [ 2.08382076e-13 -1.99000000e-02  5.43837445e-16  5.43837445e-16]
#  [ 2.52105374e-04  6.17493532e-01 -2.52827906e-01  1.39766910e-03]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.99000000e-02  0.00000000e+00 -3.94039900e-02  1.79472400e-13]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 7.64058682e-03 -2.14321859e-01  7.12237940e-01  3.41567667e-03]
#  [ 5.16243828e-03  8.04470748e-01  8.02585973e-03 -1.48542229e-01]
#  [ 4.43805546e-05  1.22465785e-01 -4.90099501e-02  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.39941645e-01  2.09261821e-02  8.98776301e-01  1.29602003e-02]
# ...

# %%
# Change the map to 10x10
import Monte_Carlo as MC
from itertools import product
from frozen_lake_env import FrozenLakeEnv
from IPython.display import clear_output
import time
import numpy as np
import matplotlib.pyplot as plt
MC.main(env = FrozenLakeEnv(map_name="10x10",is_slippery=True),map_size = 10,episodes = 45000,epsilon = 0.5)
# Out:
#   (Right)
# 🤹❄️❄️❄️❄️❄️❄️❄️❄️❄️
# ⚠️❄️❄️❄️❄️⚠️⚠️❄️❄️❄️
# ⚠️⚠️❄️❄️❄️❄️❄️❄️❄️⚠️
# ❄️❄️⚠️❄️❄️⚠️⚠️⚠️❄️❄️
# ❄️⚠️❄️❄️❄️❄️⚠️⚠️⚠️❄️
# ❄️⚠️⚠️❄️❄️⚠️❄️⚠️⚠️❄️
# ⚠️❄️❄️❄️❄️❄️❄️❄️❄️❄️
# ⚠️❄️⚠️❄️❄️❄️⚠️⚠️❄️❄️
# ❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️
# ❄️❄️❄️❄️⚠️❄️❄️❄️❄️🏆
# ...

# %%
#now use SARSA
from IPython.display import clear_output
import numpy as np
from frozen_lake_env import FrozenLakeEnv
from numpy.random import random, choice
import matplotlib.pyplot as plt
import time
from SARSA import SARSA
agent = SARSA(env = FrozenLakeEnv(map_name="10x10"))
agent.train(episodes = 1000,gamma = 1.0,alpha = 0.1,epsilon = 1.0,decay_rate = 0.1)
# Out:
# [[ 1.47681218e-01 -5.21703100e-01  8.85736535e-01  2.53633499e-01]
#  [ 9.56054122e-02  2.01458337e-02  8.84831005e-01  1.09405874e-01]
#  [ 8.23549768e-02 -1.00899903e-03  8.87990499e-01  2.46418385e-01]
#  [ 0.00000000e+00  8.90072405e-01  0.00000000e+00  1.40916696e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.90000000e-01 -2.71000000e-01 -1.00000000e-03  2.41433128e-01]
#  [-2.52008190e-02 -9.16200000e-03  3.43862260e-01  0.00000000e+00]
#  [ 6.02763664e-02  3.11041042e-02  8.84723694e-01  1.96011634e-01]
# ...

# %%
agent.test(episodes_test=1)
# Out:
#   (Right)
# 🤹❄️❄️❄️❄️❄️❄️❄️❄️❄️
# ⚠️❄️❄️❄️❄️⚠️⚠️❄️❄️❄️
# ⚠️⚠️❄️❄️❄️❄️❄️❄️❄️⚠️
# ❄️❄️⚠️❄️❄️⚠️⚠️⚠️❄️❄️
# ❄️⚠️❄️❄️❄️❄️⚠️⚠️⚠️❄️
# ❄️⚠️⚠️❄️❄️⚠️❄️⚠️⚠️❄️
# ⚠️❄️❄️❄️❄️❄️❄️❄️❄️❄️
# ⚠️❄️⚠️❄️❄️❄️⚠️⚠️❄️❄️
# ❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️
# ❄️❄️❄️❄️⚠️❄️❄️❄️❄️🏆
# steps are 20 .

# %%
# Use Q learning
import numpy as np
import pandas as pd
import time
from matplotlib import pyplot as plt
from frozen_lake_env import FrozenLakeEnv
from IPython.display import clear_output
from numpy.random import random, choice
from Q_L import QFrozenLakeAgent
import Q_L

agent = QFrozenLakeAgent(env=FrozenLakeEnv(map_name="10x10") )
agent.train()
Q_L.test(agent, num_episodes=1)
agent.plot()
# Out:
# [[ 6.94168021e-19 -6.22763353e-01  1.90785617e-05  1.09459848e-22]
#  [ 4.69835717e-32  6.21871743e-05  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  2.51554351e-11  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -9.56179250e-02  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.64827525e-02  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-2.22178641e-01 -2.14321859e-01  1.91829142e-04  9.28428577e-12]
#  [ 0.00000000e+00  0.00000000e+00  5.58485756e-04  0.00000000e+00]
#  [ 0.00000000e+00  1.53011047e-03  1.64448064e-24  1.21462895e-29]
# ...

# %%
#now use SARSA
from IPython.display import clear_output
import numpy as np
from frozen_lake_env import FrozenLakeEnv
from numpy.random import random, choice
import matplotlib.pyplot as plt
import time
from SARSA import SARSA
agent = SARSA(env = FrozenLakeEnv(map_name="12x12"))
agent.train(episodes = 1000,gamma = 1.0,alpha = 0.1,epsilon = 1.0,decay_rate = 0.1)
# Out:
# [[-1.50806274e-02 -3.60793499e-02 -1.25420803e-44 -1.57119624e-02]
#  [-7.02290560e-04 -3.43900000e-01 -1.32189948e-48 -1.90000000e-02]
#  [-2.08521119e-05 -1.00000000e-01  0.00000000e+00  0.00000000e+00]
#  [-2.29171761e-06  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-1.97674806e-02 -4.79596600e-03 -4.68559000e-01 -5.04645506e-03]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
# ...
